# %%
from autosim.simulations import AdvectionDiffusionMultichannel as Sim

# from autosim.simulations import ReactionDiffusion as Sim

sim = Sim(return_timeseries=True, log_level="warning")
data = sim.forward_samples_spatiotemporal(n=5, random_seed=42)

# %%
# Check shape
data["data"].shape

# %%
from autosim.utils import plot_spatiotemporal_video

anim = plot_spatiotemporal_video(data["data"])

# %%
from IPython.display import HTML

HTML(anim.to_jshtml())
